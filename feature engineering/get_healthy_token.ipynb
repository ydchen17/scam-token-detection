# %%
#!pip install selenium
#!pip3 install webdriver-manager

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

import time
import pandas as pd
from web3 import Web3
import shared
shared.init()

df_healthy_tokens = []
options = Options()
options.headless = False
driver = webdriver.Chrome(options=options, service=Service(ChromeDriverManager().install()))
#driver.get("https://www.google.com")

for j in range(1, 7):
    for i in range(1, 51):
            driver.get(f"https://polygonscan.com/tokens?p={j}")
            time.sleep(3)
            try:
                token_name = driver.find_element(by=By.XPATH, value=f'/html/body/div[1]/main/div[2]/div/div[2]/div/div/div[2]'
                                                          f'/div[2]/table/tbody/tr[{i}]/td[2]/div/div/h3/a').text
            except:
                driver.execute_script(f"window.scrollTo(0, 1080)")
                time.sleep(2)

            driver.find_element(by=By.XPATH, value=f'/html/body/div[1]/main/div[2]/div/div[2]/div/div/div[2]/div[2]/table/'
                                         f'tbody/tr[{i}]/td[2]/div/div/h3/a').click()
            time.sleep(3)
            token_address = driver.find_element(by=By.XPATH, value='/html/body/div[1]/main/div[4]/div[1]/div[2]/div/div[2]'
                                                         '/div[1]/div[2]/div').text
            token_address = Web3.toChecksumAddress(token_address)
            df_healthy_tokens.append([token_name, token_address])
            print(token_name, token_address)

    pd.DataFrame(df_healthy_tokens).to_csv("data/healthy_tokens_polygonscan.csv", index=False)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

import time
import pandas as pd
from web3 import Web3
import shared
shared.init()

df_healthy_tokens = []
options = Options()
options.headless = False
driver = webdriver.Chrome(options=options, service=Service(ChromeDriverManager().install()))
#driver.get("https://www.google.com")

for j in range(1, 7):
    for i in range(1, 51):
            driver.get(f"https://etherscan.io/tokens?p={j}")
            time.sleep(3)
            try:
                token_name = driver.find_element(by=By.XPATH, value=f'/html/body/div[1]/main/div[2]/div/div[2]/div/div/div[2]'
                                                          f'/div[2]/table/tbody/tr[{i}]/td[2]/div/div/h3/a').text
                
            except:
                driver.execute_script(f"window.scrollTo(0, 1080)")
                time.sleep(2)

            driver.find_element(By.XPATH, f'/html/body/div[1]/main/div[2]/div/div[2]/div/div/div[2]/div[2]/table/'
                                         f'tbody/tr[{i}]/td[2]/div/div/h3/a').click()
            time.sleep(3)
            driver.find_element(By.XPATH,'/html/body/div[1]/main/div[5]/div[1]/div[2]/div/div[2]/div[1]/div[2]/div/a[1]').click()
            token_address = driver.find_element(By.XPATH, '//*[@id="mainaddress"]').text
            token_address = Web3.toChecksumAddress(token_address)
            df_healthy_tokens.append([token_name, token_address])
            print(token_name, token_address)

    pd.DataFrame(df_healthy_tokens).to_csv("data/healthy_tokens_etherscan.csv", index=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [/Users/ydchen/.wdm/drivers/chromedriver/mac64/101.0.4951.41/chromedriver] found in cache
# Tether USD (USDT) 0xdAC17F958D2ee523a2206206994597C13D831ec7
# BNB (BNB) 0xB8c77482e45F1F44dE1745F52C74426C631bDD52
# USD Coin (USDC) 0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48
# HEX (HEX) 0x2b591e99afE9f32eAA6214f7B7629768c40Eeb39
# Binance USD (BUSD) 0x4Fabb145d64652a948d72533023f6E7A623C7C53
# Wrapped BTC (WBTC) 0x2260FAC5E5542a773Aa44fBCfeDf7C193bc2C599
# stETH (stETH) 0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84
# Wrapped liquid staked Ether 2.0 (wstETH) 0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0
# Wrapped UST Token (UST) 0xa47c8bf37f92aBed4A126BDA807A7b7498661acD
# Dai Stablecoin (DAI) 0x6B175474E89094C44Da98b954EedeAC495271d0F
# SHIBA INU (SHIB) 0x95aD61b0a150d79219dCF64E1E6Cc01f0B64C4cE
# Theta Token (THETA) 0x3883f5e181fccaF8410FA61e12b59BAd963fb645
# Bitfinex LEO Token (LEO) 0x2AF5D2aD76741191D15Dfe7bF6aC92d4Bd912Ca3
# Matic Token (MATIC) 0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0
# Cronos Coin (CRO) 0xA0b73E1Ff0B80914AB6fe0444E65848C4C34450b
# ChainLink Token (LINK) 0x514910771AF9Ca656af840dff83E8264EcF986CA
# OKB (OKB) 0x75231F58b43240C9718Dd58B4967c5114342a86c
# Uniswap (UNI) 0x1f9840a85d5aF5bf1D1762F925BDADdC4201F984
# Frax (FRAX) 0x853d955aCEf822Db058eb8505911ED77F175b99e
# Magic Internet Money (MIM) 0x99D8a9C45b2ecA8864373A26D1459e3Dff1e17F3
# VeChain (VEN) 0xD850942eF8811f2A866692A623011bDE52a462C1
# Wrapped LUNA Token (LUNA) 0xd2877702675e6cEb975b4A1dFf9fb7BAF4C91ea9
# Compound Ether (cETH) 0x4Ddc2D193948926D02f9B1fE9e1daa0718270ED5
# Wrapped Filecoin (WFIL) 0x6e1A19F235bE7ED8E3369eF73b196C07257494DE
# SAND (SAND) 0x3845badAde8e6dFF049820680d1F14bD3903a5d0
# Compound USD Coin (cUSDC) 0x39AA39c021dfbaE8faC545936693aC917d5E7563
# Chain (XCN) 0xA2cd3D43c775978A96BdBf12d733D5A1ED94fb18
# TrueUSD (TUSD) 0x0000000000085d4780B73119b644AE5ecd22b376
# Huobi BTC (HBTC) 0x0316EB71485b0Ab14103307bf65a021042c6d380
# HuobiToken (HT) 0x6f259637dcD74C767781E37Bc6133cd6A68aa161
# Wrapped Decentraland MANA (wMANA) 0xFd09Cf7cFffa9932e33668311C4777Cb9db3c9Be
# KuCoin Token (KCS) 0xf34960d9d60be18cC1D5Afc1A6F012A723a28811
# Maker (MKR) 0x9f8F72aA9304c8B593d555F12eF6589cC3A579A2
# BitTorrent (BTT) 0xC669928185DbCE49d2230CC9B0979BE6DC797957
# Pax Dollar (USDP) 0x8E870D67F660D95d5be530380D0eC0bd388289E1
# Compound Dai (cDAI) 0x5d3a536E4D6DbD6114cc1Ead35777bAB948E3643
# Graph Token (GRT) 0xc944E90C64B2c07662A292be6244BDf05Cda44a7
# BitDAO (BIT) 0x1A4b46696b2bB4794Eb3D4c26f1c55F9170fa4C5
# Quant (QNT) 0x4a220E6096B25EADb88358cb44068A3248254675
# Compound USDT (cUSDT) 0xf650C3d88D12dB855b8bf7D11Be6C55A4e07dCC9
# Wrapped Celo (wCELO) 0xE452E6Ea2dDeB012e20dB73bf5d3863A3Ac8d77a
# Nexo (NEXO) 0xB62132e35a6c13ee1EE0f84dC5d40bad8d815206
# Fantom Token (FTM) 0x4E15361FD6b4BB609Fa63C81A2be19d873717870
# Frax Share (FXS) 0x3432B6A60D23Ca0dFCa7761B7ab56459D9C964D0
# Paxos Gold (PAXG) 0x45804880De22913dAFE09f4980848ECE6EcbAf78
# Zilliqa (ZIL) 0x05f4a42e251f2d52b8ed15E9FEdAacFcEF1FAD27
# Gnosis (GNO) 0x6810e776880C02933D47DB1b9fc05908e5386b96
# Fei USD (FEI) 0x956F47F50A910163D8BF957Cf5846D573E7f87CA
# Synthetix Network Token (SNX) 0xC011a73ee8576Fb46F5E1c5751cA3B9Fe0af2a6F
# BAT (BAT) 0x0D8775F648430679A709E98d2b0Cb6250d2887EF
# EnjinCoin (ENJ) 0xF629cBd94d3791C9250152BD8dfBDF380E2a3B9c
# chiliZ (CHZ) 0x3506424F91fD33084466F402d5D97f05F8e3b4AF
# Amp (AMP) 0xfF20817765cB7f73d4bde2e66e067E58D11095C2
# Aave interest bearing CRV (aCRV) 0x8dAE6Cb04688C62d939ed9B68d32Bc62e49970b1
# XinFin XDCE (XDCE) 0x41AB1b6fcbB2fA9DCEd81aCbdeC13Ea6315F2Bf2
# Lido DAO Token (LDO) 0x5A98FcBEA516Cf06857215779Fd812CA3beF1B32
# LoopringCoin V2 (LRC) 0xBBbbCA6A901c926F240b89EacB641d8Aec7AEafD
# Gala (GALA) 0x15D4c048F83bd7e37d49eA4C83a07267Ec4203dA
# NXM (NXM) 0xd7c49CEE7E9188cCa6AD8FF264C1DA2e69D4Cf3B
# HarmonyOne (ONE) 0x799a4202c12ca952cB311598a024C80eD371a41e
# Compound (COMP) 0xc00e94Cb662C3520282E6f5717214004A7f26888
# HoloToken (HOT) 0x6c6EE5e31d828De241282B9606C8e98Ea48526E2
# Tether Gold (XAUt) 0x68749665FF8D2d112Fa859AA293F07A622782F38
# Celsius (CEL) 0xaaAEBE6Fe48E54f431b0C390CfaF0b017d09D42d
# WQtum (WQTUM) 0x3103dF8F05c4D8aF16fD22AE63E406b97FeC6938
# yearn.finance (YFI) 0x0bc529c00C6401aEF6D220BE8C6Ea1667F6Ad93e
# Bancor (BNT) 0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C
# OMG Network (OMG) 0xd26114cd6EE289AccF82350c8d8487fedB8A0C07
# Livepeer Token (LPT) 0x58b6A8A3302369DAEc383334672404Ee733aB239
# 1INCH Token (1INCH) 0x111111111117dC0aa78b770fA6A738034120C302
# HUSD (HUSD) 0xdF574c24545E5FfEcb9a659c229253D4111d87e1
# Serum (SRM) 0x476c5E26a75bd202a9683ffD34359C0CC15be0fF
# IOSToken (IOST) 0xFA1a856Cfa3409CFa145Fa4e20Eb270dF3EB21ab
# Synapse (SYN) 0x0f2D719407FdBeFF09D87557AbB7232601FD9F29
# Rocket Pool (RPL) 0xD33526068D116cE69F19A9ee46F0bd304F21A51f
# Rocket Pool (RPL) 0xB4EFd85c19999D84251304bDA99E90B92300Bd93
# Synapse (SYN) 0x0f2D719407FdBeFF09D87557AbB7232601FD9F29
# Rocket Pool (RPL) 0xD33526068D116cE69F19A9ee46F0bd304F21A51f
# Rocket Pool (RPL) 0xB4EFd85c19999D84251304bDA99E90B92300Bd93
# SushiToken (SUSHI) 0x6B3595068778DD592e39A122f4f5a5cF09C90fE2
# SwissBorg (CHSB) 0xba9d4199faB4f26eFE3551D490E3821486f135Ba
# APENFT (NFT) 0x198d14F2Ad9CE69E76ea330B374DE4957C3F850a
# Gemini dollar (GUSD) 0x056Fd409E1d7A124BD7017459dFEa2F387b6d5Cd
# renBTC (renBTC) 0xEB4C2781e4ebA804CE9a9803C67d0893436bB27D
# WAX Token (WAX) 0x39Bb259F66E1C59d5ABEF88375979b4D20D98022
# Illuvium (ILV) 0x767FE9EDC9E0dF98E07454847909b5E959D7ca0E
# Swipe (SXP) 0x8CE9137d39326AD0cD6491fb5CC0CbA0e089b6A9
# Golem Network Token (GLM) 0x7DD9c5Cba05E151C895FDe1CF355C9A1D5DA6429
# Render Token (RNDR) 0x6De037ef9aD2725EB40118Bb1702EBb27e4Aeb24
# Wootrade Network (WOO) 0x4691937a7508860F876c9c0a2a617E7d9E945D4B
# Smooth Love Potion (SLP) 0xCC8Fa225D80b9c7D42F96e9570156c65D6cAAa25
# Ethereum Name Service (ENS) 0xC18360217D8F7Ab5e7c516566761Ea12Ce7F9D72
# dYdX (DYDX) 0x92D6C1e31e14520e676a687F0a93788B716BEff5
# UMA Voting Token v1 (UMA) 0x04Fa0d235C4abf4BcF4787aF4CF447DE572eF828
# XSGD (XSGD) 0x70e8dE73cE538DA2bEEd35d14187F6959a8ecA96
# MXCToken (MXC) 0x5Ca381bBfb58f0092df149bD3D243b08B9a8386e
# Polymath (POLY) 0x9992eC3cF6A55b00978cdDF2b27BC6882d88D1eC
# CoinEx Token (CET) 0x081F67aFA0cCF8c7B17540767BBe95DF2bA8D97F
# Anyswap (ANY) 0xf99d58e463A2E07e5692127302C20A191861b4D6
# Kyber Network Crystal v2 (KNC) 0xdeFA4e8a7bcBA345F687a2f1456F5Edd9CE97202
# STASIS EURS Token (EURS) 0xdB25f211AB05b1c97D595516F45794528a807ad8
# Telcoin (TEL) 0x467Bccd9d29f223BcE8043b84E8C8B282827790F
# Tribe (TRIBE) 0xc7283b66Eb1EB5FB86327f08e1B5816b0720212B
# CEEK (CEEK) 0xb056c38f6b7Dc4064367403E26424CD2c60655e1
# Orbs (ORBS) 0xff56Cc6b1E6dEd347aA0B7676C85AB0B3D08B0FA
# StatusNetwork (SNT) 0x744d70FDBE2Ba4CF95131626614a1763DF805B9E
# Synth sUSD (sUSD) 0x57Ab1ec28D129707052df4dF418D58a2D46d5f51
# Spell Token (SPELL) 0x090185f2135308BaD17527004364eBcC2D37e5F6
# Divi Exchange Token (DIVX) 0x13f11C9905A08ca76e3e853bE63D4f0944326C72
# Chroma (CHR) 0x8A2279d4A90B6fe1C4B30fa660cC9f926797bAA2
# KEEP Token (KEEP) 0x85Eee30c52B0b379b046Fb0F85F4f3Dc3009aFEC
# Injective Token (INJ) 0xe28b3B32B6c345A34Ff64674606124Dd5Aceca30
# Pundi X Token (PUNDIX) 0x0FD10b9899882a6f2fcb5c371E17e70FdEe00C38
# Fetch (FET) 0xaea46A60368A7bD060eec7DF8CBa43b7EF41Ad85
# Rari Governance Token (RGT) 0xD291E7a03283640FDc51b121aC401383A46cC623
# DENT (DENT) 0x3597bfD533a99c9aa083587B074434E61Eb0A258
# FunFair (FUN) 0x419D0d8BdD9aF5e606Ae2232ed285Aff190E711b
# BitMax token (BTMX) 0xcca0c9c383076649604eE31b20248BC04FdF61cA
# Ankr Eth2 Reward Bearing Certificate (aETHc) 0xE95A203B1a91a908F9B9CE46459d101078c2c3cb
# Balancer (BAL) 0xba100000625a3754423978a60c9317c58a424e3D
# XY Oracle (XYO) 0x55296f69f40Ea6d20E478533C15A6B08B654E758
# OriginToken (OGN) 0x8207c1FfC5B6804F6024322CcF34F29c3541Ae26
# Function X (FX) 0x8c15Ef5b4B21951d50E53E4fbdA8298FFAD25057
# Ocean Token (OCEAN) 0x967da4048cD07aB37855c090aAF366e4ce1b9F48
# PowerLedger (POWR) 0x595832F8FC6BF59c85C527fEC3740A1b7a361269
# Aurora (AURORA) 0xAaAAAA20D9E0e2461697782ef11675f668207961
# Energy Web Token Bridged (EWTB) 0x178c820f862B14f316509ec36b13123DA19A6054
# Iron Bank EUR (ibEUR) 0x96E61422b6A9bA0e068B6c5ADd4fFaBC6a4aae27
# Adshares (ADS) 0xcfcEcFe2bD2FED07A9145222E8a7ad9Cf1Ccd22A
# Trace (TRAC) 0xaA7a9CA87d3694B5755f213B5D04094b8d0F0A6F
# MEDX TOKEN (MEDX) 0xfd1e80508F243E64CE234eA88A5Fd2827c71D4b7
# Sai Stablecoin v1.0 (SAI) 0x89d24A6b4CcB1B6fAA2625fE562bDD9a23260359
# Request (REQ) 0x8f8221aFbB33998d8584A2B05749bA73c37a938a
# Mask Network (MASK) 0x69af81e73A73B40adF4f3d4223Cd9b1ECE623074
# CelerToken (CELR) 0x4F9254C83EB525f9FCf346490bbb3ed28a81C667
# Numeraire (NMR) 0x1776e1F26f98b1A5dF9cD347953a26dd3Cb46671
# AlphaToken (ALPHA) 0xa1faa113cbE53436Df28FF0aEe54275c13B40975
# HooToken (HOO) 0xD241D7b5cb0eF9fC79D9e4eb9e21F5e209f52f7D
# BetProtocolToken (BEPRO) 0xCF3C8Be2e2C42331Da80EF210e9B1b307C03d36A
# StormX (STMX) 0xbE9375C6a420D2eEB258962efB95551A5b722803
# Dawn (DAWN) 0x580c8520dEDA0a441522AEAe0f9F7A5f29629aFa
# Reputation (REPv2) 0x221657776846890989a759BA2973e427DfF5C9bB
# Reserve Rights (RSR) 0x320623b8E4fF03373931769A31Fc52A4E78B5d70
# PlatonCoin (PLTC) 0x429D83Bb0DCB8cdd5311e34680ADC8B12070a07f
# QuarkChain Token (QKC) 0xEA26c4aC16D4a5A106820BC8AEE85fd0b7b2b664
# Wrapped Celo USD (wCUSD) 0xad3E3Fc59dff318BecEaAb7D00EB4F68b1EcF195
# Boba Token (BOBA) 0x42bBFa2e77757C645eeaAd1655E0911a7553Efbc
# Dawn (DAWN) 0x580c8520dEDA0a441522AEAe0f9F7A5f29629aFa
# BetProtocolToken (BEPRO) 0xCF3C8Be2e2C42331Da80EF210e9B1b307C03d36A
# Reserve Rights (RSR) 0x320623b8E4fF03373931769A31Fc52A4E78B5d70
# QuarkChain Token (QKC) 0xEA26c4aC16D4a5A106820BC8AEE85fd0b7b2b664
# KyberNetwork (KNC) 0xdd974D5C2e2928deA5F71b9825b8b646686BD200
# PlatonCoin (PLTC) 0x429D83Bb0DCB8cdd5311e34680ADC8B12070a07f
# Wrapped Celo USD (wCUSD) 0xad3E3Fc59dff318BecEaAb7D00EB4F68b1EcF195
# Boba Token (BOBA) 0x42bBFa2e77757C645eeaAd1655E0911a7553Efbc
# Bifrost (BFC) 0x0c7D5ae016f806603CB1782bEa29AC69471CAb9c
# BandToken (BAND) 0xBA11D00c5f74255f56a5E366F4F77f5A186d7f55
# ELF (ELF) 0xbf2179859fc6D5BEE9Bf9158632Dc51678a4100e
# Storj (STORJ) 0xB64ef51C888972c908CFacf59B47C1AfBC0Ab8aC
# Origin Dollar (OUSD) 0x2A8e1E676Ec238d8A992307B495b45B3fEAa5e86
# FLOKI (FLOKI) 0xcf0C122c6b73ff809C693DB761e7BaeBe62b6a2E
# STPT (STPT) 0xDe7D85157d9714EADf595045CC12Ca4A5f3E2aDb
# CoinDash Token (CDT) 0x177d39AC676ED1C67A2b268AD7F1E58826E5B0af
# Metal (MTL) 0xF433089366899D83a9f26A773D59ec7eCF30355e
# Uquid Coin (UQC) 0x8806926Ab68EB5a7b909DcAf6FdBe5d93271D6e2
# FOX (FOX) 0xc770EEfAd204B5180dF6a14Ee197D99d808ee52d
# TORN Token (TORN) 0x77777FeDdddFfC19Ff86DB637967013e6C6A116C
# NKN (NKN) 0x5Cf04716BA20127F1E2297AdDCf4B5035000c9eb
# Dusk Network (DUSK) 0x940a2dB1B7008B6C776d4faaCa729d6d4A4AA551
# mStable USD (mUSD) 0xe2f2a5C287993345a840Db3B0845fbC70f5935a5
# RLC (RLC) 0x607F4C5BB672230e8672085532f7e901544a7375
# TrueFi (TRU) 0x4C19596f5aAfF459fA38B0f7eD92F11AE6543784
# Proton (XPR) 0xD7EFB00d12C2c13131FD319336Fdf952525dA2af
# Propy (PRO) 0x226bb599a12C826476e3A771454697EA52E9E220
# Token Prometeus Network (PROM) 0xfc82bb4ba86045Af6F327323a46E80412b91b27d
# Veritaseum (VERI) 0x8f3470A7388c05eE4e7AF3d01D8C722b0FF52374
# Covalent Query Token (CQT) 0xD417144312DbF50465b1C641d016962017Ef6240
# Aragon Network Token (ANT) 0xa117000000f279D81A1D3cc75430fAA017FA5A2e
# UniBright (UBT) 0x8400D94A5cb0fa0D041a3788e395285d61c9ee5e
# Reputation (REPv2) 0x221657776846890989a759BA2973e427DfF5C9bB
# FEGtoken (FEG) 0x389999216860AB8E0175387A0c90E5c52522C945
# USDK (USDK) 0x1c48f86ae57291F7686349F12601910BD8D470bb
# ZEON (ZEON) 0xE5B826Ca2Ca02F09c1725e9bd98d9a8874C30532
# EthLend (LEND) 0x80fB784B7eD66730e8b1DBd9820aFD29931aab03
# Decentral Games (DG) 0x4b520c812E8430659FC9f12f6d0c39026C83588D
# Aergo (AERGO) 0x91Af0fBB28ABA7E31403Cb457106Ce79397FD4E6
# QASH (QASH) 0x618E75Ac90b12c6049Ba3b27f5d5F8651b0037F6
# bZx Protocol Token (BZRX) 0x56d811088235F11C8920698a204A5010a788f4b3
# ALICE (ALICE) 0xAC51066d7bEC65Dc4589368da368b212745d63E8
# BTRFLY (BTRFLY) 0xC0d4Ceb216B3BA9C3701B291766fDCbA977ceC3A
# AIOZ Network (AIOZ) 0x626E8036dEB333b408Be468F951bdB42433cBF18
# CarryToken (CRE) 0x115eC79F1de567eC68B7AE7eDA501b406626478e
# Mainframe Token (MFT) 0xDF2C7238198Ad8B389666574f2d8bc411A4b7428
# RHOC (RHOC) 0x168296bb09e24A88805CB9c33356536B980D3fC5
# Melon Token (MLN) 0xec67005c4E498Ec7f55E092bd1d35cbC47C91892
# BOX Token (BOX) 0xe1A178B681BD05964d3e3Ed33AE731577d9d96dD
# Automata (ATA) 0xA2120b9e674d3fC3875f415A7DF52e382F141225
# Beta Token (BETA) 0xBe1a001FE942f96Eea22bA08783140B9Dcc09D28
# Kin (KIN) 0x818Fc6C2Ec5986bc6E2CBf00939d90556aB12ce5
# Wrapped NXM (wNXM) 0x0d438F3b5175Bebc262bF23753C1E53d03432bDE
# SpookyToken (BOO) 0x55aF5865807b196bD0197e0902746F31FBcCFa58
# Rupiah Token (IDRT) 0x998FFE1E43fAcffb941dc337dD0468d52bA5b48A
# OVR (OVR) 0x21BfBDa47A0B4B5b1248c767Ee49F7caA9B23697
# Adventure Gold (AGLD) 0x32353A6C91143bfd6C7d363B546e62a9A2489A20
# Gitcoin (GTC) 0xDe30da39c46104798bB5aA3fe8B9e0e1F348163F
# LCX (LCX) 0x037A54AaB062628C9Bbae1FDB1583c195585fe41
# Reserve (RSV) 0x196f4727526eA7FB1e17b2071B3d8eAA38486988
# HOPR Token (HOPR) 0xF5581dFeFD8Fb0e4aeC526bE659CFaB1f8c781dA
# Quickswap (QUICK) 0x6c28AeF8977c9B773996d0e8376d2EE379446F2f
# QANX Token (QANX) 0xAAA7A10a8ee237ea61E8AC46C50A8Db8bCC1baaa
# Refereum (RFR) 0xd0929d411954c47438dc1d871dd6081F5C5e149c
# Aurora DAO (AURA) 0xCdCFc0f66c522Fd086A1b725ea3c0Eeb9F9e8814
# Ribbon (RBN) 0x6123B0049F904d730dB3C36a31167D9d4121fA6B
# Marlin POND (POND) 0x57B946008913B82E4dF85f501cbAeD910e58D26C
# CocosToken (COCOS) 0x0C6f5F7D555E7518f6841a79436BD2b1Eef03381
# Presearch (PRE) 0xEC213F83defB583af3A000B1c0ada660b1902A0F
# BitMartToken (BMC) 0x986EE2B944c42D017F52Af21c4c69B84DBeA35d8
# Quickswap (QUICK) 0x6c28AeF8977c9B773996d0e8376d2EE379446F2f
# QANX Token (QANX) 0xAAA7A10a8ee237ea61E8AC46C50A8Db8bCC1baaa
# Aurora DAO (AURA) 0xCdCFc0f66c522Fd086A1b725ea3c0Eeb9F9e8814
# Marlin POND (POND) 0x57B946008913B82E4dF85f501cbAeD910e58D26C
# Presearch (PRE) 0xEC213F83defB583af3A000B1c0ada660b1902A0F
# BitMartToken (BMC) 0x986EE2B944c42D017F52Af21c4c69B84DBeA35d8
# BioPassport Coin (BIOT) 0xc07A150ECAdF2cc352f5586396e344A6b17625EB
# DIAToken (DIA) 0x84cA8bc7997272c7CfB4D0Cd3D55cd942B3c9419
# Moss Coin (MOC) 0x865ec58b06bF6305B886793AA20A2da31D034E68
# Guaranteed Entrance Token (GET) 0x8a854288a5976036A725879164Ca3e91d30c6A1B
# Fuse Token (FUSE) 0x970B9bB2C0444F5E81e9d0eFb84C8ccdcdcAf84d
# Nectar (NCT) 0x9E46A38F5DaaBe8683E10793b06749EEF7D733d1
# Somnium Space Cubes (CUBE) 0xDf801468a808a32656D2eD2D2d80B72A129739f4
# Civilization (CIV) 0x37fE0f067FA808fFBDd12891C0858532CFE7361d
# BarnBridge Governance Token (BOND) 0x0391D2021f89DC339F60Fff84546EA23E337750f
# SENTINEL PROTOCOL (UPP) 0xC86D054809623432210c107af2e3F619DcFbf652
# Shiden (SDN) 0x00E856ee945A49bb73436e719D96910Cd9D116a4
# Student Coin (STC) 0x15B543e986b8c34074DFc9901136d9355a537e7E
# ICONOMI (ICN) 0x888666CA69E0f178DED6D75b5726Cee99A87D698
# GRID (GRID) 0x12B19D3e2ccc14Da04FAe33e63652ce469b3F2FD
# LON Token (LON) 0x0000000000095413afC295d19EDeb1Ad7B71c952
# Ultiledger (ULT) 0xE884cc2795b9c45bEeac0607DA9539Fd571cCF85
# Pinakion (PNK) 0x93ED3FBe21207Ec2E8f2d3c3de6e058Cb73Bc04d
# BZ (BZ) 0x4375E7aD8A01B8eC3Ed041399f62D9Cd120e0063
# Metronome (MET) 0xa3d58c4E56fedCae3a7c43A725aeE9A71F0ece4e
# Wirex Token (WXT) 0xa02120696c7B8fE16C09C749E4598819b2B0E915
# Ampleforth Governance (FORTH) 0x77FbA179C79De5B7653F68b5039Af940AdA60ce0
# Tellor Tributes (TRB) 0x88dF592F8eb5D7Bd38bFeF7dEb0fBc02cf3778a0
# LockTrip (LOC) 0x5e3346444010135322268a4630d2ED5F8D09446c
# MATH Token (MATH) 0x08d967bb0134F2d07f7cfb6E246680c53927DD30
# Kryll (KRL) 0x464eBE77c293E473B48cFe96dDCf88fcF7bFDAC0
# MANTRA DAO (OM) 0x3593D125a4f7849a1B059E64F4517A86Dd60c95d
# NAGA Coin (NGC) 0x72dD4b6bd852A3AA172Be4d6C5a6dbEc588cf131
# Rarible (RARI) 0xFca59Cd816aB1eaD66534D82bc21E7515cE441CF
# Quantstamp (QSP) 0x99ea4dB9EE77ACD40B119BD1dC4E33e1C070b80d
# Bluzelle (BLZ) 0x5732046A883704404F284Ce41FfADd5b007FD668
# Measurable Data Token (MDT) 0x814e0908b12A99FeCf5BC101bB5d0b8B5cDf7d26
# DEXTools (DEXT) 0xfB7B4564402E5500dB5bB6d63Ae671302777C75a
# Cortex Coin (CTXC) 0xEa11755Ae41D889CeEc39A63E6FF75a02Bc1C00d
# Bytom (BTM) 0xcB97e65F07DA24D46BcDD078EBebd7C6E6E3d750
# ParaSwap (PSP) 0xcAfE001067cDEF266AfB7Eb5A286dCFD277f3dE5
# CargoX (CXO) 0xb6EE9668771a79be7967ee29a63D4184F8097143
# Blockport (BPT) 0x327682779bAB2BF4d1337e8974ab9dE8275A7Ca8
# Yuan Chain New (YCC) 0x37E1160184F7dD29f00b78C050Bf13224780b0B0
# Litentry (LIT) 0xb59490aB09A0f526Cc7305822aC65f2Ab12f9723
# Fusion (FSN) 0xD0352a019e9AB9d757776F532377aAEbd36Fd541
# CRPT (CRPT) 0x08389495D7456E1951ddF7c3a1314A4bfb646d8B
# SelfKey (KEY) 0x4CC19356f2D37338b9802aa8E8fc58B0373296E7
# Nuls (NULS) 0xa2791BdF2D5055Cda4d46EC17f9F429568275047
# Parsiq Token (PRQ) 0x362bc847A3a9637d3af6624EeC853618a43ed7D2
# Frontier Token (FRONT) 0xf8C3527CC04340b208C854E985240c02F7B7793f
# WaykiCoin (WIC) 0x4f878C0852722b0976A955d68B376E4Cd4Ae99E5
# Vader (VADER) 0x2602278EE1882889B946eb11DC0E810075650983
# QRL (QRL) 0x697beac28B09E122C4332D163985e8a73121b97F
# veCRV-DAO yVault (yveCRV-DAO) 0xc5bDdf9843308380375a611c18B50Fb9341f502A
# Interest Compounding ETH Index (icETH) 0x7C07F7aBe10CE8e33DC6C5aD68FE033085256A84
# Eden (EDEN) 0x1559FA1b8F28238FD5D76D9f434ad86FD20D1559
# STAKE (STAKE) 0x0Ae055097C6d159879521C384F1D2123D1f195e6
# SAN (SAN) 0x7C5A0CE9267ED19B22F8cae653F198e3E8daf098
# Instadapp (INST) 0x6f40d4A6237C257fff2dB00FA0510DeEECd303eb
# Stratos Token (STOS) 0x08c32b0726C5684024ea6e141C50aDe9690bBdcc
# Pluton (PLU) 0xD8912C10681D8B21Fd3742244f44658dBA12264E
# NimiqNetwork (NET) 0xcfb98637bcae43C13323EAa1731cED2B716962fD
# PAID Network (PAID) 0x1614F18Fc94f47967A3Fbe5FfcD46d4e7Da3D787
# ANGLE (ANGLE) 0x31429d1856aD1377A8A0079410B297e1a9e214c2
# UniCrypt (UNCX) 0xaDB2437e6F65682B85F814fBc12FeC0508A7B1D0
# UTN-P: Universa Token (UTNP) 0x9e3319636e2126e3c0bc9e3134AEC5e1508A46c7
# Dock (DOCK) 0xE5Dada80Aa6477e85d09747f2842f7993D0Df71C
# BOSAGORA (BOA) 0x746DdA2ea243400D5a63e0700F190aB79f06489e
# StackOS (STACK) 0x56A86d648c435DC707c8405B78e2Ae8eB4E60Ba4
# NUM Token (NUM) 0x3496B523e5C00a4b4150D6721320CdDb234c3079
# InsurAce (INSUR) 0x544c42fBB96B39B21DF61cf322b5EDC285EE7429
# FOAM Token (FOAM) 0x4946Fcea7C692606e8908002e55A582af44AC121
# OCC (OCC) 0x2F109021aFe75B949429fe30523Ee7C0D5B27207
# ERC20 (ERC20) 0xc3761EB917CD790B30dAD99f6Cc5b4Ff93C4F9eA
# 0chain (ZCN) 0xb9EF770B6A5e12E45983C5D80545258aA38F3B78
# ELYSIA (EL) 0x2781246fe707bB15CeE3e5ea354e2154a2877B16
# THORSwap Token (THOR) 0xa5f2211B9b8170F694421f2046281775E8468044
# Switcheo Token (SWTH) 0xB4371dA53140417CBb3362055374B10D97e420bB
# ELYSIA (EL) 0x2781246fe707bB15CeE3e5ea354e2154a2877B16
# AOG (AOG) 0x8578530205CEcbe5DB83F7F29EcfEEC860C297C2
# Imported GBYTE (GBYTE) 0x31F69dE127C8A0fF10819C0955490a4Ae46fcc2a
# Antimatter.Finance Governance Token (MATTER) 0x9B99CcA871Be05119B2012fd4474731dd653FEBe
